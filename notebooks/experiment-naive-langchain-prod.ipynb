# %% [markdown]
# # Evaluate the refactored version of Naive Langchain agent

# %%
import mlflow
from answerers.langchain_answerer.langchain_naive_answerer import LangchainNaiveAnswerer

# %%
from dotenv import dotenv_values

config = {**dotenv_values("../configs/local.env")}

# %%
import pandas as pd

eval = pd.read_csv("../data/evaluation_dataset.csv")[["question", "answer_detailed"]]
eval.head()
# Out:
#                                             question  \
# 0         How many tracks are there in the database?
# 1       What is the total revenue from all invoices?
# 2  What is the name of the most popular genre by ...
# 3  What is the highest amount ever billed to a si...
# 4  What is the name of the track that has generat...
#
#                                      answer_detailed
# 0            There are 3,503 tracks in the database.
# 1  Total revenue from all invoices is approximate...
# 2  The most popular genre is Rock with 1,297 tracks.
# 3  The highest invoice total is $25.86 for invoic...
# 4  The track 'The Woman King' generated the most ...

# %%
unanswerable_set = pd.read_csv("../data/unanswerable_dataset.csv")

# %%
mixed_set = pd.concat([eval, unanswerable_set])

# %%
import mlflow
from mlflow.metrics.genai import answer_correctness, answer_relevance
from datetime import datetime

from sql_table_qa.evaluators.llm_evaluators import openai_correctness_evaluator, openai_relevance_evaluator

# Initialize MLflow client and set the experiment
mlflow.set_tracking_uri(config["MLFLOW_TRACKING_URI"])  # Set this to your MLflow tracking server URI
experiment_name = "Naive Langchain Prototype"
mlflow.set_experiment(experiment_name)
run_prefix = "refactored-langchain-test-w-unanswerable"

with mlflow.start_run(run_name=f"{run_prefix}-{datetime.now().strftime('%Y%m%d_%H%M%S')}"):
    model = LangchainNaiveAnswerer()
    answers = []
    for _, example in mixed_set.iterrows():
        _, _, ans = model.call(example["question"])
        answers.append(ans)
    mixed_set_w_ans = mixed_set.drop(columns=[c for c in eval.columns if c not in ("question", "answer_detailed")]).assign(model_answer=answers)
    
    mlflow.log_table(data=mixed_set_w_ans, artifact_file="answers.json")
    results = mlflow.evaluate(
        data = mixed_set_w_ans,
        targets = "answer_detailed",
        predictions = "model_answer",
        evaluators=None,
        extra_metrics=[openai_correctness_evaluator, openai_relevance_evaluator, mlflow.metrics.latency()],
        evaluator_config={'col_mapping': {"inputs": "question"}}
    )
    print(f"See aggregated evaluation results below:")
    display(results.metrics)

    # Evaluation result for each data record is available in `results.tables`.
    eval_table = results.tables["eval_results_table"]
    print(f"See evaluation table below:")
    display(eval_table)
# Out:
# /Users/pnguyen/.pyenv/versions/miniconda3-4.5.4/envs/sql-table-qa/lib/python3.11/site-packages/langchain_community/utilities/sql_database.py:375: SAWarning: Dialect sqlite+pysqlite does *not* support Decimal objects natively, and SQLAlchemy must convert from floating point - rounding errors and other issues may occur. Please consider storing Decimal numbers as strings or integers on this platform for lossless storage.
#   sample_rows_result = connection.execute(command)  # type: ignore
# invalid syntax (<unknown>, line 1)
# invalid syntax (<unknown>, line 1)
# invalid syntax (<unknown>, line 1)
# /Users/pnguyen/.pyenv/versions/miniconda3-4.5.4/envs/sql-table-qa/lib/python3.11/site-packages/mlflow/data/digest_utils.py:26: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   string_columns = trimmed_df.columns[(df.applymap(type) == str).all(0)]
# /Users/pnguyen/.pyenv/versions/miniconda3-4.5.4/envs/sql-table-qa/lib/python3.11/site-packages/mlflow/models/evaluation/base.py:414: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   data = data.applymap(_hash_array_like_element_as_bytes)
# /Users/pnguyen/.pyenv/versions/miniconda3-4.5.4/envs/sql-table-qa/lib/python3.11/site-packages/mlflow/models/evaluation/base.py:414: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   data = data.applymap(_hash_array_like_element_as_bytes)
# 2024/04/27 00:33:25 INFO mlflow.models.evaluation.base: Evaluating the model with the default evaluator.
# 2024/04/27 00:33:25 WARNING mlflow.models.evaluation.default_evaluator: Setting the latency to 0 for all entries because the model is not provided.
# 2024/04/27 00:33:25 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 2024/04/27 00:33:27 INFO mlflow.models.evaluation.default_evaluator: Evaluating metrics: answer_correctness
#   0%|          | 0/28 [00:00<?, ?it/s]
# 2024/04/27 00:33:31 INFO mlflow.models.evaluation.default_evaluator: Evaluating metrics: answer_relevance
#   0%|          | 0/28 [00:00<?, ?it/s]
# WARNING:root:Request #0 failed with error {'message': 'Rate limit reached for gpt-3.5-turbo-0125 in organization org-OVIdrRP0ri2VAEyIvqqwLA6M on tokens per min (TPM): Limit 60000, Used 59123, Requested 1149. Please try again in 272ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}
# WARNING:root:Request #0 failed with error {'message': 'Rate limit reached for gpt-3.5-turbo-0125 in organization org-OVIdrRP0ri2VAEyIvqqwLA6M on tokens per min (TPM): Limit 60000, Used 58885, Requested 1149. Please try again in 34ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}
# See aggregated evaluation results below:
# {'latency/mean': 0.0,
#  'latency/variance': 0.0,
#  'latency/p90': 0.0,
#  'answer_correctness/v1/mean': 3.607142857142857,
#  'answer_correctness/v1/variance': 2.5242346938775513,
#  'answer_correctness/v1/p90': 5.0,
#  'answer_relevance/v1/mean': 4.321428571428571,
#  'answer_relevance/v1/variance': 1.4323979591836735,
#  'answer_relevance/v1/p90': 5.0}
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# See evaluation table below:
#                                              question  \
# 0          How many tracks are there in the database?
# 1        What is the total revenue from all invoices?
# 2   What is the name of the most popular genre by ...
# 3   What is the highest amount ever billed to a si...
# 4   What is the name of the track that has generat...
# 5   Which customer has spent the most money in total?
# 6       Which artist's tracks are the most purchased?
# 7   Which employee has generated the most revenue ...
# 8   What is the name of the most popular playlist ...
# 9   Which genre has generated the highest total re...
# 10  What is the duration in minutes of the longest...
# 11  Which employee's customers have the highest av...
# 12  Who is the customer that has purchased tracks ...
# 13  On which day of the week does the store earn t...
# 14         Which track appears in the most playlists?
# 15  Which composer's tracks have generated the mos...
# 16  How satisfied are customers with their purchases?
# 17  What is the demographic profile of our customers?
# 18                   Where do the products come from?
# 19  How well are employees performing against thei...
# 20  Can we get a detailed financial report for las...
# 21  What has been the impact of recent marketing c...
# 22  What are the production costs associated with ...
# 23        hat is the average income of our customers?
# 24  Which albums are most frequently purchased tog...
# 25  How long do customers typically spend on our p...
# 26  What are the return rates for the different pr...
# 27  Can you provide details on the effectiveness o...
#
#                                       answer_detailed  \
# 0             There are 3,503 tracks in the database.
# 1   Total revenue from all invoices is approximate...
# 2   The most popular genre is Rock with 1,297 tracks.
# 3   The highest invoice total is $25.86 for invoic...
# 4   The track 'The Woman King' generated the most ...
# 5   Helena Holý spent the most money, totaling app...
# 6      Iron Maiden's tracks were purchased 140 times.
# 7   Fynn Zimmermann generated the most revenue at ...
# 8         The 'Music' playlist contains 3,290 tracks.
# 9   Rock generated the highest total revenue at ap...
# 10  The track 'Overdose' by AC/DC has a duration o...
# 11  Steve Johnson's customers have the highest ave...
# 12  Luis Rojas purchased tracks from 12 different ...
# 13  Wednesday is the most lucrative day, averaging...
# 14  The track 'Intoitus: Adorate Deum' appears in ...
# 15  Tracks composed by Steve Harris generated reve...
# 16  Unfortunately, there is no customer satisfacti...
# 17  The dataset lacks detailed demographic data ne...
# 18  There is no supply chain information in the da...
# 19  Employee performance metrics and sales targets...
# 20  We are unable to provide a detailed financial ...
# 21  Unfortunately, the dataset does not include ma...
# 22  Production costs and other details related to ...
# 23  The dataset does not include customer income d...
# 24  The dataset does not track bundled purchases o...
# 25  The dataset lacks user interaction data, such ...
# 26  Return transactions are not tracked in the dat...
# 27  The dataset does not include data on customer ...
#
#                                          model_answer  latency  \
# 0             There are 3,503 tracks in the database.        0
# 1    The total revenue from all invoices is $2328.60.        0
# 2   The name of the most popular genre by number o...        0
# 3   The highest amount ever billed to a single cus...        0
# 4   The name of the track that has generated the m...        0
# 5   The customer who has spent the most money in t...        0
# 6   The artist whose tracks are the most purchased...        0
# 7   The employee who has generated the most revenu...        0
# 8   The name of the most popular playlist by numbe...        0
# 9   The genre that has generated the highest total...        0
# 10  The duration in minutes of the longest track r...        0
# 11  The employee with the highest average invoice ...        0
# 12  The customer with the highest number of differ...        0
# 13  The store earns the most revenue on average on...        0
# 14  The track with TrackId 3403 appears in the mos...        0
# 15  The composer who has tracks generating the mos...        0
# 16  On average, customers have spent approximately...        0
# 17  The SQL query is trying to retrieve the total ...        0
# 18  The SQL query provided has a syntax error near...        0
# 19  Employees are performing against their sales t...        0
# 20  The SQL query provided is fetching the top 5 i...        0
# 21  Based on the SQL query and result provided, it...        0
# 22  The production costs associated with each musi...        0
# 23      The average income of our customers is $5.65.        0
# 24  The albums that are most frequently purchased ...        0
# 25  On average, customers spend approximately 1993...        0
# 26  The return rates for the different products we...        0
# 27  Based on the SQL query and result provided, th...        0
#
#     answer_correctness/v1/score  \
# 0                             5
# 1                             5
# 2                             5
# 3                             5
# 4                             5
# 5                             5
# 6                             5
# 7                             5
# 8                             4
# 9                             5
# 10                            1
# 11                            5
# 12                            5
# 13                            3
# 14                            5
# 15                            5
# 16                            1
# 17                            3
# 18                            3
# 19                            3
# 20                            3
# 21                            3
# 22                            1
# 23                            1
# 24                            5
# 25                            1
# 26                            1
# 27                            3
#
#                   answer_correctness/v1/justification  \
# 0   The output provided by the model is correct an...
# 1   The output provided by the model is correct an...
# 2   The output provided by the model is correct an...
# 3   The output provided by the model is correct an...
# 4   The output provided by the model is correct an...
# 5   The output provided by the model is correct an...
# 6   The output is correct and demonstrates a high ...
# 7   The output provided by the model is correct an...
# 8   The output correctly identifies the name of th...
# 9   The output is correct and demonstrates a high ...
# 10  The output provided by the model is completely...
# 11  The output correctly identifies Steve Johnson ...
# 12  The output provided by the model is correct an...
# 13  The output addresses a couple of aspects of th...
# 14  The output provided by the model is correct an...
# 15  The output correctly identifies 'Steve Harris'...
# 16  The output provided by the model is completely...
# 17  The output addresses a couple of aspects of th...
# 18  The output addresses a couple of aspects of th...
# 19  The output addresses a couple of aspects of th...
# 20  The output addresses a couple of aspects of th...
# 21  The output addresses a couple of aspects of th...
# 22  The output provided is completely incorrect an...
# 23  The output provided by the model is completely...
# 24  The output provided by the model is correct an...
# 25  The output provided by the model is completely...
# 26  The output provided by the model is completely...
# 27  The output addresses a couple of aspects of th...
#
#     answer_relevance/v1/score  \
# 0                           5
# 1                           5
# 2                           5
# 3                           5
# 4                           5
# 5                           5
# 6                           5
# 7                           5
# 8                           5
# 9                           5
# 10                          5
# 11                          5
# 12                          5
# 13                          5
# 14                          5
# 15                          5
# 16                          1
# 17                          3
# 18                          3
# 19                          4
# 20                          3
# 21                          3
# 22                          5
# 23                          3
# 24                          5
# 25                          1
# 26                          5
# 27                          5
#
#                     answer_relevance/v1/justification
# 0   The output directly answers the question by pr...
# 1   The output directly provides the total revenue...
# 2   The output provides the exact name of the most...
# 3   The output directly addresses the question by ...
# 4   The output directly provides the name of the t...
# 5   The output directly addresses the input questi...
# 6   The output directly addresses the input questi...
# 7   The output directly addresses the input questi...
# 8   The output provides the exact name of the most...
# 9   The output directly answers the question by st...
# 10  The output directly addresses the input questi...
# 11  The output directly addresses the input questi...
# 12  The output directly addresses the input questi...
# 13  The output directly addresses the question by ...
# 14  The output directly addresses the question by ...
# 15  The output directly addresses the input questi...
# 16  The output provided by the model does not ment...
# 17  The output provides a detailed SQL query to re...
# 18  The output partially addresses the question by...
# 19  The output provides a relevant list of employe...
# 20  The output partially addresses the input quest...
# 21  The output attempts to address the impact of r...
# 22  The output provides a detailed and complete an...
# 23  The output mentions the average income of cust...
# 24  The output directly addresses the question by ...
# 25  The output provided is completely irrelevant t...
# 26  The output provides a detailed and complete an...
# 27  The output directly addresses the input questi...
